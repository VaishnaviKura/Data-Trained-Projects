describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
# Checking how the data has been distriubted in each column
plt.figure(figsize=(20,25))
plotnumber = 1

for column in data:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(20,25))
plotnumber = 1

for column in data:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Runs and Errors')
sns.scatterplot(data['R'],data['E'],hue=data["W"]);
plt.xlabel("Runs")
plt.ylabel("Errors")
# Out:
# Text(0, 0.5, 'Errors')

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparision between Runs and Hits')
sns.scatterplot(data['R'],data['H'],hue=data["W"],data="husl");
plt.xlabel("Runs")
plt.ylabel("Hits")
# Out:
# Text(0, 0.5, 'Hits')

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between  and Hits')
sns.scatterplot(data['RA'],data['ERA'],hue=data['W'],palette="husl");
plt.xlabel("Runs Allowed")
plt.ylabel("Earned Run Average")
# Out:
# Text(0, 0.5, 'Earned Run Average')

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Walks and Wins ')
sns.lineplot(data['BB'],data['W']) 
plt.xlabel("Walks")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Runs Allowed and Wins')
sns.scatterplot(data['RA'],data['W']);
plt.xlabel("Runs Allowed")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision between Earned Runs and Wins')
sns.scatterplot(data['ER'],data['W']);
plt.xlabel("Earned Runs")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %%
# Checking the pairwise relation in the dataset.
sns.pairplot(data)

# %%
data.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
# Removing Outliers

data.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
# Can be removed by z-score

from scipy.stats import zscore

z=np.abs(zscore(data[["R","ERA","SHO","SV","E"]]))

z
# Out:
# array([[0.61907797, 0.50695519, 0.81462859, 1.67160651, 0.46146963],
#        [0.13443166, 0.25459752, 0.1728    , 0.24987932, 0.60719689],
#        [0.33290586, 0.64134684, 0.32091429, 0.65485616, 1.11724227],
#        [1.14641931, 0.05301004, 0.56777144, 0.78410408, 0.48575751],
#        [0.01327008, 1.53131824, 0.1728    , 1.04259994, 0.60719689],
#        [3.50964704, 0.35016492, 0.32091429, 1.17184786, 0.46146963],
#        [1.31142984, 0.16500309, 1.80205719, 0.6376231 , 0.0971515 ],
#        [0.4286812 , 0.20980031, 0.32091429, 0.00861653, 1.26296953],
#        [0.76562578, 0.48455658, 0.1728    , 2.18859821, 0.04857575],
#        [1.03448909, 0.79216414, 0.32091429, 0.39636031, 0.194303  ],
#        [1.08641548, 0.63537388, 0.56777144, 0.24987932, 1.79730279],
#        [0.70562195, 0.86533293, 0.41965715, 0.52560823, 0.68006051],
#        [0.47137623, 0.03658439, 0.1728    , 0.37912725, 0.0971515 ],
#        [0.55792022, 0.45618501, 0.1728    , 0.24987932, 0.02428788],
#        [0.09981406, 0.41138779, 0.91337145, 1.94733542, 2.30734817],
#        [0.71369939, 2.2764453 , 0.91337145, 2.44709406, 0.12143938],
#        [0.15174045, 1.67168286, 0.41965715, 1.41311066, 2.01589367],
#        [0.01327008, 1.33570372, 2.39451435, 0.6376231 , 1.21439378],
#        [0.57522902, 0.72496831, 1.06148574, 0.39636031, 1.57871191],
#        [0.83486097, 0.83696136, 0.81462859, 1.04259994, 0.31574238],
#        [0.0905827 , 1.17891346, 0.6665143 , 0.89611895, 0.46146963],
#        [0.25559323, 0.75333989, 0.41965715, 0.26711238, 0.31574238],
#        [1.30219848, 0.14260448, 0.1728    , 1.04259994, 1.26296953],
#        [1.99455036, 1.01615023, 0.32091429, 0.1206314 , 0.31574238],
#        [1.07718413, 1.64331129, 1.06148574, 1.04259994, 1.65157553],
#        [0.36752345, 1.15651485, 2.39451435, 0.50837518, 1.40869678],
#        [0.13443166, 0.52935379, 1.6539429 , 0.26711238, 1.1901059 ],
#        [0.54984278, 0.1874017 , 0.1728    , 0.1206314 , 0.60719689],
#        [0.661773  , 0.29939474, 1.30834289, 0.26711238, 0.17001513],
#        [0.84409233, 2.42726261, 1.80205719, 0.91335201, 0.04857575]])

# %%
d1= data[(z<3).all(axis=1)]
d1
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
d1.shape
# Out:
# (29, 17)

# %%
data
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
data.shape
# Out:
# (30, 17)

# %%
#checking data loss

data_loss = (30-29)/30*100
data_loss
# Out:
# 3.3333333333333335

# %%
s_features = ["CG", "SHO", "SV", "E"]

# %%
# Using yeo-johnson method to remove the skewness
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# %%
d1[s_features] = scaler.fit_transform(d1[s_features].values)
d1[s_features].head()
# Out:
#          CG       SHO        SV         E
# 0 -0.307098 -0.787002  1.532753 -0.348265
# 1 -0.307098  0.236737  0.312020 -0.540820
# 2  2.011315 -0.252844 -0.664137 -1.326125
# 3  1.264463 -0.513555 -0.820689  0.650818
# 4  1.264463  0.236737 -1.149165 -0.540820

# %%
d1['H'] = np.log(d1['H'])

# %%
d1.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738423
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %%
features_skewed = ["H","CG", "SHO", "SV", "E"]
plt.figure(figsize=(20,25))
plotnumber = 1

for column in d1[["R","ERA","SHO","SV","E"]]:
    if plotnumber<=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(d1[column])
        plt.xlabel(column)
    plotnumber+=1
plt.show()

# %%
# Checking the correlation between features and the target
cor = d1.corr()
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0
# RA  -0.642749 -0.625996  0.231036
# ER  -0.640161 -0.604541  0.165556
# ERA -0.640503 -0.619790  0.138692
# CG   0.208515 -0.302413 -0.070484
# SHO  1.000000  0.196672 -0.206739
# SV   0.196672  1.000000 -0.032529
# E   -0.206739 -0.032529  1.000000

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(12,9))
sns.heatmap(d1.corr(),linewidths=.1,fmt='0.2f', cmap="Blues_r", annot = True)
plt.xticks(rotation=45);
plt.yticks(rotation=45);

# %%
plt.figure(figsize=(18,7))
d1.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('target',fontsize=14)
plt.title('correlation between lanel and feature using bar plot',fontsize=18)
plt.show()

# %%
d1.drop("H", axis=1, inplace=True)

# %%
d1.drop("CG", axis=1, inplace=True)

# %%
d1.head()
# Out:
#     W    R    AB   2B  3B   HR   BB    SO   SB   RA   ER   ERA       SHO  \
# 0  95  724  5575  300  42  139  383   973  104  641  601  3.73 -0.787002
# 1  83  696  5467  277  44  156  439  1264   70  700  653  4.07  0.236737
# 2  81  669  5439  303  29  141  533  1157   86  640  584  3.67 -0.252844
# 3  76  622  5533  260  27  136  404  1231   68  701  643  3.98 -0.513555
# 4  74  689  5605  289  49  151  455  1259   83  803  746  4.64  0.236737
#
#          SV         E
# 0  1.532753 -0.348265
# 1  0.312020 -0.540820
# 2 -0.664137 -1.326125
# 3 -0.820689  0.650818
# 4 -1.149165 -0.540820

# %%
# Seperating individual variables

x = d1.drop("W", axis=1)
y = d1["W"]

# %%
x.shape
# Out:
# (29, 14)

# %%
y.shape
# Out:
# (29,)

# %%
x.head()
# Out:
#      R    AB   2B  3B   HR   BB    SO   SB   RA   ER   ERA       SHO  \
# 0  724  5575  300  42  139  383   973  104  641  601  3.73 -0.787002
# 1  696  5467  277  44  156  439  1264   70  700  653  4.07  0.236737
# 2  669  5439  303  29  141  533  1157   86  640  584  3.67 -0.252844
# 3  622  5533  260  27  136  404  1231   68  701  643  3.98 -0.513555
# 4  689  5605  289  49  151  455  1259   83  803  746  4.64  0.236737
#
#          SV         E
# 0  1.532753 -0.348265
# 1  0.312020 -0.540820
# 2 -0.664137 -1.326125
# 3 -0.820689  0.650818
# 4 -1.149165 -0.540820

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#            R        AB        2B        3B        HR        BB        SO  \
# 0   0.959398  0.830084  1.556538  1.010845 -0.765863 -1.536359 -2.727623
# 1   0.331147 -0.702831  0.201171  1.208917 -0.181389 -0.495021  0.121896
# 2  -0.274666 -1.100253  1.733325 -0.276617 -0.697101  1.252941 -0.925866
# 3  -1.329231  0.233951 -0.800621 -0.474688 -0.869006 -1.145857 -0.201246
# 4   0.174084  1.255894  0.908319  1.704094 -0.353293 -0.197495  0.072935
# 5   1.856900  0.716535 -0.093474 -1.266972  1.743939  1.643442 -0.240414
# 12 -0.629176  0.515620  0.575226  0.437572  0.236737  0.312020  0.161388
# 13 -0.234429  0.557272  0.389399  0.393434  0.908147 -2.498840  1.810553
# 14 -0.629176 -2.275049 -2.269360 -2.254827  0.908147  2.084917  0.311562
# 15  0.642788 -1.289290 -1.497462 -1.658968  0.468029  1.333006  1.669209
# 16  0.511205 -1.122683 -1.297340 -1.327935  2.090856  0.677176  1.203715
# 17  0.028736  0.668344  0.646698  0.702398 -1.075340 -0.365006  1.430810
# 18  2.221778  0.904370  0.903998  0.812742 -0.787002 -1.149165 -0.167685
# 19 -1.418671 -1.053264 -1.140102 -1.173453  0.691583  0.906024 -0.348265
# 20 -1.155506 -0.747817 -0.854214 -0.754146  0.468029 -0.221934 -0.167685
# 21  1.256840 -0.150808  0.017745  0.128608  0.236737 -1.149165 -1.588197
# 22 -0.629176  0.987674  0.875409  0.989293 -0.252844  0.183904 -0.167685
# 23  0.204180  1.667986  1.604423  1.607220 -1.075340 -1.149165  1.472959
# 24 -1.067784 -1.303174 -1.197279 -1.151385  2.090856  0.558509 -1.870191
# 25  0.423484 -0.858889 -0.568326 -0.533457  1.521828 -0.221934 -1.454792
# 26  2.134056  0.335129  0.317927  0.172746  0.236737  0.183904 -0.540820
# 27 -0.058985  0.585040  0.260750  0.283090 -1.381412 -0.221934  0.001905
# 28  0.598927  2.153924  2.319144  2.379630 -2.064039 -0.982264  0.237592

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30, random_state=i)
    mod = LinearRegression()
    mod.fit(x_train, y_train)
    pred = mod.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is ",maxAccu," on Random_state ",maxRS)
# Out:
# Maximum r2 score is  0.9097540105382932  on Random_state  104

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRS)

# %%
from sklearn.linear_model import LinearRegression, Lasso,Ridge
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
# Linear Regression
LR = LinearRegression()
LR.fit(x_train,y_train)

# prediction
predLR=LR.predict(x_test)
print('R2_score:',r2_score(y_test,predLR))

# Mean Absolute Error (MAE)
print('MAE:',metrics.mean_absolute_error(y_test, predLR))

# Mean Squared Error (MSE)
print('MSE:',metrics.mean_squared_error(y_test, predLR))

# Root Mean Squared Error (RMSE)
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predLR)))
# Out:
# R2_score: 0.9097540105382932
# MAE: 2.8597181915389376
# MSE: 11.932525273270121
# RMSE: 3.454348748066721

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
paramsRidge = {'alpha':[0.01, 0.1, 1.0,10.26], 'solver' : ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']}
ridge=Ridge()
clf=GridSearchCV(ridge,paramsRidge)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10.26, 'solver': 'saga'}

# %%
# Checking R2 score for Ridge regressor
ridge=Ridge(alpha=10.26,solver='sag')
ridge.fit(x_train,y_train)
ridge.score(x_train,y_train)
pred_ridge=ridge.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_ridge))
print('MAE:',metrics.mean_absolute_error(y_test, pred_ridge))
print('MSE:',metrics.mean_squared_error(y_test, pred_ridge))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, pred_ridge)))
# Out:
# R2_Score: 0.7948339545663569
# MAE: 4.27327777150764
# MSE: 27.127510451781703
# RMSE: 5.208407669507227

# %%
#Lasso Regressor

from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
lasso=Lasso()
clf=GridSearchCV(lasso,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
lasso=Lasso(alpha=1,random_state=0)
lasso.fit(x_train,y_train)
lasso.score(x_train,y_train)
pred_lasso=lasso.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_lasso))
print('MAE:',metrics.mean_absolute_error(y_test, pred_lasso))
print('MSE:',metrics.mean_squared_error(y_test, pred_lasso))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_Score: 0.8328047650206478
# MAE: 4.21638135850204
# MSE: 22.10692551393656
# RMSE: 4.701800241815528

# %%
SGD=SGDRegressor()
SGD.fit(x_train,y_train)

# prediction
predSGD=SGD.predict(x_test)
print('R2_Score:',r2_score(y_test,predSGD))
print('MAE:',metrics.mean_absolute_error(y_test, predSGD))
print('MSE:',metrics.mean_squared_error(y_test, predSGD))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predSGD)))
# Out:
# R2_Score: 0.9422002087273458
# MAE: 1.9162285006976008
# MSE: 7.642416846050946
# RMSE: 2.764492149753901

# %%
from sklearn.model_selection import cross_val_score

# Checking cv score for Linear Regression
print(cross_val_score(LR,x,y,cv=5).mean())
# Out:
# 0.15921112291547704

# %%
# Checking cv score for Ridge Regression
print(cross_val_score(ridge,x,y,cv=5).mean())
# Out:
# 0.3770790858481373

# %%
# Checking cv score for Lasso Regression
print(cross_val_score(lasso,x,y,cv=5).mean())
# Out:
# 0.5072274071281603

# %%
# Checking cv score for SGD Regression
print(cross_val_score(SGD,x,y,cv=5).mean())
# Out:
# 0.2440437209448457

# %%
# HyperParameter Tuning

from sklearn.model_selection import GridSearchCV

# %%
# Lasso Regressor
parameters = {'alpha':[0.01, 0.1, 1.0,10.26],
              'selection':['cyclic','random'],
              'max_iter':[2,4,6,8,10],
              'tol':[100,1000],
              'fit_intercept':['bool']}

# %%
GCV=GridSearchCV(Lasso(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
GCV.best_params_
# Out:
# {'alpha': 0.01,
#  'fit_intercept': 'bool',
#  'max_iter': 2,
#  'selection': 'random',
#  'tol': 100}

# %%
# Creating final model
Case_study = Lasso(alpha=1.0, fit_intercept="bool", max_iter=2, selection="random", tol=100)
Case_study.fit(x_train, y_train)
pred = Case_study.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_lasso)*100)
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_Score: 83.28047650206479
# RMSE value: 4.701800241815528

# %%
# Saving the model

import joblib
joblib.dump(Case_study,"Evaluation_Case_Study.pkl")
# Out:
# ['Evaluation_Case_Study.pkl']
